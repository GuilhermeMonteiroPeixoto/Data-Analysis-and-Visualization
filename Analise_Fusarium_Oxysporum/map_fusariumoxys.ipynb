# %% [markdown]
# # Map Fusarium Oxysporum
#
# Guilherme O. Monteiro Peixoto

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data_fusarium = pd.read_csv('fusarium - Página1 (1).csv')
data_fusarium
# Out:
#             Region   Latitude   Longitude Presence Extent Last Reported  \
# 0            Benin    43960.0        2.25  Present    NaN  Not recorded
# 1     Burkina Faso    43963.0  -166667.00  Present    NaN  Not recorded
# 2          Burundi       -3.5       30.00  Present    NaN  Not recorded
# 3         Cameroon        6.0    43963.00  Present    NaN  Not recorded
# 4          Comoros -1223333.0  4444553.00  Present    NaN  Not recorded
# ..             ...        ...         ...      ...    ...           ...
# 134  French Guiana        4.0      -53.00  Present    NaN  Not recorded
# 135         Guyana        5.0      -59.00  Present    NaN  Not recorded
# 136           Peru      -10.0      -75.25  Present    NaN  Not recorded
# 137       Suriname        4.0      -56.00  Present    NaN  Not recorded
# 138      Venezuela        8.0      -66.00  Present    NaN  Not recorded
#
#          Origin First Reported Invasiveness
# 0    Introduced   Not recorded     Invasive
# ...

# %%
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 93 kB 2.5 MB/s eta 0:00:011
# ...

# %%
locations = data_fusarium[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[1]
# Out:
# [43963.0, -166667.0]

# %%
import folium
map = folium.Map(location=[38.9, -77.05], zoom_start=2)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=data_fusarium['Region'][point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
