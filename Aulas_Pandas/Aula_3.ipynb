# %% [markdown]
# # Aula 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# link studentdata: https://www.kaggle.com/spscientist/students-performance-in-exams
studentdata = pd.read_csv('datasets_74977_169835_StudentsPerformance.csv')

# %%
#Conditional selection

print('Math Score menor que 30')
data2 = studentdata[['gender','parental level of education',
                              'writing score','reading score','math score']].loc[(studentdata['math score'] <= 30)]
data2
# Out:
# Math Score menor que 30
#      gender parental level of education  writing score  reading score  \
# 17   female            some high school             28             32
# 59   female            some high school             10             17
# 76     male            some high school             22             26
# 91     male                 high school             36             34
# 145  female                some college             33             39
# 327    male                some college             19             23
# 338  female            some high school             27             38
# 363  female            some high school             32             34
# 466  female          associate's degree             38             31
# 528  female           bachelor's degree             47             41
# 596    male                 high school             15             24
# 601  female                 high school             30             29
# 683  female            some high school             44             40
# 787  female                some college             32             38
# 842  female                 high school             36             44
# 980  female                 high school             23             24
#
#      math score
# 17           18
# 59            0
# 76           30
# 91           27
# 145          22
# 327          28
# 338          24
# 363          27
# 466          26
# 528          29
# 596          30
# 601          29
# 683          29
# 787          19
# 842          23
# 980           8

# %%
data2 = studentdata[['gender','parental level of education',
                              'writing score','reading score','math score']].loc[(studentdata['writing score'] == 100) |
                                                                                 (studentdata['reading score'] == 100) |
                                                                                 (studentdata['math score'] == 100)]
data2
# Out:
#      gender parental level of education  writing score  reading score  \
# 106  female             master's degree            100            100
# 114  female           bachelor's degree            100            100
# 149    male          associate's degree             93            100
# 165  female           bachelor's degree            100            100
# 179  female            some high school            100            100
# 377  female             master's degree            100             95
# 381    male          associate's degree             95            100
# 403  female                 high school            100             99
# 451  female                some college             97             92
# 458  female           bachelor's degree            100            100
# 546  female            some high school             97            100
# 566  female           bachelor's degree            100            100
# 594  female           bachelor's degree             99            100
# 623    male                some college             86             96
# 625    male                some college             99             97
# 685  female             master's degree            100             99
# 712  female                some college             99            100
# 886  female          associate's degree             95            100
# 903  female           bachelor's degree            100            100
# 916    male           bachelor's degree            100            100
# 957  female             master's degree            100            100
# 962  female          associate's degree            100            100
# 970  female           bachelor's degree            100            100
#
#      math score
# 106          87
# 114          99
# 149         100
# 165          96
# 179          97
# 377          85
# 381          87
# 403          88
# 451         100
# 458         100
# 546          92
# 566          92
# 594          92
# 623         100
# 625         100
# 685          94
# 712          98
# 886          93
# 903          93
# 916         100
# 957          92
# 962         100
# 970          89

# %%
data2 = studentdata[['gender','parental level of education',
                              'writing score','reading score','math score']].loc[(studentdata['gender'] == 'female') &
                                                                                 (studentdata['math score'] >= 95)]
data2
# Out:
#      gender parental level of education  writing score  reading score  \
# 114  female           bachelor's degree            100            100
# 165  female           bachelor's degree            100            100
# 179  female            some high school            100            100
# 263  female                 high school             90             93
# 451  female                some college             97             92
# 458  female           bachelor's degree            100            100
# 503  female          associate's degree             92             89
# 712  female                some college             99            100
# 717  female          associate's degree             99             96
# 855  female           bachelor's degree             96             97
# 962  female          associate's degree            100            100
#
#      math score
# 114          99
# 165          96
# 179          97
# 263          99
# 451         100
# 458         100
# 503          95
# 712          98
# 717          96
# 855          97
# 962         100

# %%
data2 = studentdata[['gender','parental level of education',
                              'writing score','reading score','math score']].loc[(studentdata['parental level of education'] == 'some college')]
data2
# Out:
#      gender parental level of education  writing score  reading score  \
# 1    female                some college             88             90
# 4      male                some college             75             78
# 6    female                some college             92             95
# 7      male                some college             39             43
# 13     male                some college             70             72
# ..      ...                         ...            ...            ...
# 976    male                some college             60             62
# 983  female                some college             91             87
# 989  female                some college             83             86
# 998  female                some college             77             78
# 999  female                some college             86             86
#
#      math score
# 1            69
# 4            76
# 6            88
# 7            40
# 13           78
# ..          ...
# 976          60
# 983          78
# 989          67
# 998          68
# 999          77
#
# [226 rows x 5 columns]
